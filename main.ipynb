# %% [markdown]
# <h2 align=center style="line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="green">
# فاز دوم - پروژه درس داده کاوی
# </font>
# </h2>
#
# <h5 align=center style="line-height:100%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="orange">
# محمدمهدی اسمعیلیان یزدی - ۶۱۰۳۰۲۱۱۳
# </font>
# </h5>
# <h5 align=center style="line-height:100%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="orange">
# ریحانه صابر - ۶۱۰۳۰۳۱۵۷
# </font>
# </h5>

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- اضافه کردن کتابخانه های مورد نیاز ---------------
# </font>
# </h3>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- بارگذاری داده‌ها ---------------
# </font>
# </h3>

# %%
df = pd.read_csv("data.csv")
print(df.shape)
df.head()
# Out:
# (100000, 35)
#         f1                             f2                             f3  \
# 0  Source1            2020-12-24 10:08:43            2020-12-24 11:08:43
# 1  Source1  2022-06-09 16:01:34.000000000  2022-06-09 17:16:23.000000000
# 2  Source2            2016-10-14 11:12:59            2016-10-14 11:56:56
# 3  Source1            2020-05-29 18:17:05            2020-05-29 19:17:05
# 4  Source2            2020-02-18 09:36:33            2020-02-18 10:22:00
#
#           f4          f5         f6          f7     f8  \
# 0  42.687721 -123.392106  42.690302 -123.393621  0.194
# 1  41.268605  -73.606244  41.275247  -73.577968  1.538
# 2  30.758549  -98.226692        NaN         NaN  0.010
# 3  34.134470  -78.875060  34.134470  -78.875060  0.000
# 4  30.381618  -97.651863        NaN         NaN  0.000
#
#                                                   f9             f10  ...  \
# 0  A crash has occurred causing no to minimum del...           I-5 N  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 35 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   f1      100000 non-null  str
#  1   f2      100000 non-null  str
#  2   f3      100000 non-null  str
#  3   f4      100000 non-null  float64
#  4   f5      100000 non-null  float64
#  5   f6      55869 non-null   float64
#  6   f7      55869 non-null   float64
#  7   f8      100000 non-null  float64
#  8   f9      100000 non-null  str
#  9   f10     99862 non-null   str
#  10  f11     99999 non-null   str
#  11  f12     100000 non-null  str
#  12  f13     100000 non-null  str
#  13  f14     99716 non-null   str
#  14  f15     98437 non-null   str
#  15  f16     97867 non-null   float64
#  16  f17     97746 non-null   float64
#  17  f18     98142 non-null   float64
#  18  f19     97683 non-null   float64
#  19  f20     97702 non-null   str
#  20  f21     92564 non-null   float64
# ...

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- بررسی مقادیر تکراری و گمشده ---------------
# </font>
# </h3>

# %%
duplicates = df.duplicated().sum()
print('Duplicates:', duplicates)
# Out:
# Duplicates: 18

# %%
# TODO: Rremove Dupliacates

# %%
missing = pd.DataFrame({
    'Missing': df.isnull().sum(),
    'Percent': (df.isnull().sum()/len(df))*100
}).sort_values('Percent', ascending=False)

missing.head(35)
# Out:
#      Missing  Percent
# f6     44131   44.131
# f7     44131   44.131
# f22    28673   28.673
# f21     7436    7.436
# f19     2317    2.317
# f20     2298    2.298
# f17     2254    2.254
# f16     2133    2.133
# f18     1858    1.858
# f15     1563    1.563
# f34      305    0.305
# f14      284    0.284
# f10      138    0.138
# f11        1    0.001
# f27        0    0.000
# f29        0    0.000
# f28        0    0.000
# f25        0    0.000
# f30        0    0.000
# f31        0    0.000
# f32        0    0.000
# f33        0    0.000
# f26        0    0.000
# f1         0    0.000
# f24        0    0.000
# f23        0    0.000
# f2         0    0.000
# f13        0    0.000
# f12        0    0.000
# f9         0    0.000
# f8         0    0.000
# f5         0    0.000
# f4         0    0.000
# f3         0    0.000
# y          0    0.000

# %%
plt.figure(figsize=(10,6))
missing['Percent'].head(30).plot(kind='bar')
plt.title('Missing Values Percentage')
plt.show()

# %%
# TODO: handle missing data (remove the columns or putting the mean)

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- تشخیص و حذف داده های پرت ---------------
# </font>
# </h3>

# %%
# TODO

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- تحلیل داده اکتشافی ---------------
# </font>
# </h3>

# %%
# TODO

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- مهندسی فیچرها ---------------
# </font>
# </h3>

# %%
# TODO

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- انتخاب فیچرها ---------------
# </font>
# </h3>

# %%
# TODO

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- PCA ---------------
# </font>
# </h3>

# %%
# TODO

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- بررسی مدل های مختلف ---------------
# </font>
# </h3>

# %%
# TODO

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- انتخاب مدل مناسب ---------------
# </font>
# </h3>

# %%
# TODO

# %% [markdown]
# <h3 align=center style="direction: rtl; line-height:200%;font-family:vazirmatn;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# --------------- ارزیابی و گزارش مدل نهایی ---------------
# </font>
# </h3>

# %%
# TODO
